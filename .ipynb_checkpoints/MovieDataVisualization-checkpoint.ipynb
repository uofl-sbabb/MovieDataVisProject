# %% [markdown]
# # Movie Data Visualization Project:

# %%
# import needed libraries:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
# load movie dataset:
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tmdb/tmdb-movie-metadata")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 8.89M/8.89M [00:00<00:00, 26.7MB/s]
# Extracting files...
# Path to dataset files: C:\Users\sydne\.cache\kagglehub\datasets\tmdb\tmdb-movie-metadata\versions\2

# %%
# install needed dependency:
pip install kagglehub[pandas-datasets]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# from kaggle.api.kaggle_api_extended import KaggleApi
# api = KaggleApi()
# api.authenticate()
# # Replace 'dataset-owner/dataset-name' with the actual path from the Kaggle URL
# api.dataset_download_files('dataset-owner/dataset-name', path='./', unzip=True)

# %%
# Install needed libraries:
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = f"{path}\tmdb_5000_movies.csv"

# Load the latest version
movies_df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "tmdb/tmdb-movie-metadata",
  file_path
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

movies_df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\kagglehub\exceptions.py:67, in handle_call(fn, resource_handle)
#      66 try:
# ---> 67     return fn()
#      68 except requests.HTTPError as e:
#
# File ~\anaconda3\lib\site-packages\kagglehub\http_resolver.py:144, in DatasetHttpResolver._resolve.<locals>.<lambda>()
#     143 os.makedirs(os.path.dirname(out_path), exist_ok=True)
# --> 144 response = handle_call(lambda: api_client.datasets.dataset_api_client.download_dataset(r), h)
#     145 download_file(response, out_path, h, extract_auto_compressed_file=True)
#
# File ~\anaconda3\lib\site-packages\kagglesdk\datasets\services\dataset_api_service.py:93, in DatasetApiClient.download_dataset(self, request)
#      91   request = ApiDownloadDatasetRequest()
# ...
