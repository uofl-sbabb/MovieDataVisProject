# %% [markdown]
# # Movie Data Visualization Project:

# %%
# import needed libraries:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
# load movie dataset:
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tmdb/tmdb-movie-metadata")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\sydne\.cache\kagglehub\datasets\tmdb\tmdb-movie-metadata\versions\2

# %%
# install needed dependency:
#pip install "kagglehub[pandas-datasets]"

# %%
# Install needed libraries:
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "tmdb_5000_movies.csv"

# Load the latest version
movies_df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "tmdb/tmdb-movie-metadata",
  file_path,
  pandas_kwargs={
        "encoding": "latin-1",
        "engine": "python",
        "on_bad_lines": "skip",
        "quotechar": '"'
    }
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

movies_df.head()
# Out:
#                          ºýÞûªkðÃFR´òç©è$ýãFV=ý~[  \
# 0  íð±´FÅÙ{9+Úä²3çYj|éyañÃÜXå%ÁÊ|nè%ÆÊµu9-¤ñ}...
# 1     å-I8b6
# yË$Bsýè|ÛËÏÃ86vëª¾CRBà´´Ææö$7æ±
# 2  §¯¿õô¢mé\gÜwÎXÒÙ-]ÔTôîVÒ
# ÕeYßÕÜ!É+_¤...
# 3                                                  Ò
# 4  \ßÏ<ïÐóluøªîNÕºUpt\*¹
# ÍkVmê_+RôÀöÑªhð¡
# ¹A¶§...
#
#   ¥Û®êkYmÜºm'º¾u;1/Jºj7u'4
# Sÿ{öüggÅôìì;'È\çì¬K]ðÎÎþ/×ÙñcÌ¦Õõ4EûÃªízP¼²HçY1<ù¯gî¢ëVß=zt{{;7¢Í²¦%
# ÑÚ=rý<ÏãÝWð£$Ü¿ç¤/1=gRv±ÿü OiÎzûUÂ0KöGµ+A¼50;4pRue¼z¤¹1¶¦ïÌaçºe×Ð7-÷ÇæIx¢í12¼ýM½´ðæ°  \
# 0                                                NaN
# 1  ª©#èmÝæð<5m8U'PVî<÷ìeåt
# éÝdÂí:ÂYF¬J9...
# 2                                               None
# 3  ÍØ£Sê'ÁvZI÷yÏ§)¯
# 1mo­ñ´Ãþ£÷¼_jïÎº¼...
# 4                                               None
#
#    8ðpcP
# 3%}Dc7x~d Unnamed: 3
# 0               None       None
# 1  äÔéj¾lY×ó&P7Â¡¿       None
# 2               None       None
# 3               None       None
# 4               None       None
